# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
file_path = "drug200.csv"
df = pd.read_csv(file_path)
df.head(10)
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY
# 5   22   F  NORMAL        HIGH    8.607  drugX
# 6   49   F  NORMAL        HIGH   16.275  drugY
# 7   41   M     LOW        HIGH   11.037  drugC
# 8   60   M  NORMAL        HIGH   15.171  drugY
# 9   43   M     LOW      NORMAL   19.368  drugY

# %%
df.shape
# Out:
# (200, 6)

# %%
X = df[['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K']].values
X[0:5]
# Out:
# array([[23, 'F', 'HIGH', 'HIGH', 25.355],
#        [47, 'M', 'LOW', 'HIGH', 13.093],
#        [47, 'M', 'LOW', 'HIGH', 10.114],
#        [28, 'F', 'NORMAL', 'HIGH', 7.798],
#        [61, 'F', 'LOW', 'HIGH', 18.043]], dtype=object)

# %%
y = df[['Drug']]
y[0:5]
# Out:
#     Drug
# 0  drugY
# 1  drugC
# 2  drugC
# 3  drugX
# 4  drugY

# %%
from sklearn import preprocessing
le_Sex = preprocessing.LabelEncoder()
le_Sex.fit(['F','M', 'UNKNOWN'])
X[:,1] = le_Sex.transform(X[:,1])

le_BP = preprocessing.LabelEncoder()
le_BP.fit(['LOW', 'NORMAL', 'HIGH'])
X[:,2] = le_BP.transform(X[:,2])

le_Ch = preprocessing.LabelEncoder()
le_Ch.fit(['NORMAL', 'HIGH'])
X[:,3] = le_Ch.transform(X[:,3])

X[0:10]
# Out:
# array([[23, 0, 0, 0, 25.355],
#        [47, 1, 1, 0, 13.093],
#        [47, 1, 1, 0, 10.114],
#        [28, 0, 2, 0, 7.798],
#        [61, 0, 1, 0, 18.043],
#        [22, 0, 2, 0, 8.607],
#        [49, 0, 2, 0, 16.275],
#        [41, 1, 1, 0, 11.037],
#        [60, 1, 2, 0, 15.171],
#        [43, 1, 1, 1, 19.368]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3 , random_state = 3)

# %%
X_train.shape , X_test.shape
# Out:
# ((140, 5), (60, 5))

# %% [markdown]
# ## Modeling

# %%
drugTree = DecisionTreeClassifier(criterion = "entropy", max_depth = 5)
drugTree
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
drugTree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %% [markdown]
# ### Predict

# %%
y_pred = drugTree.predict(X_test)

# %%
print(y_pred [0:8])
print(y_test [0:8])
# Out:
# ['drugY' 'drugX' 'drugX' 'drugX' 'drugX' 'drugC' 'drugY' 'drugA']
#       Drug
# 40   drugY
# 51   drugX
# 139  drugX
# 197  drugX
# 170  drugX
# 82   drugC
# 183  drugY
# 46   drugA

# %% [markdown]
# ### Evaluation

# %%
from sklearn import metrics
print("DecisionTrees Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# DecisionTrees Accuracy: 0.9833333333333333

# %%
# !pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in c:\users\hello\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\hello\anaconda3\lib\site-packages (from pydotplus) (3.0.9)

# %%
from io import StringIO
import pydotplus
import matplotlib.image as mpimg
from sklearn import tree

# %%
pip install graphViz
# Out:
# Requirement already satisfied: graphViz in c:\users\hello\anaconda3\lib\site-packages (0.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
dot_data = StringIO()
filename = "drugtree.png"
featureNames = df.columns[0:5]
out=tree.export_graphviz(drugTree,feature_names=featureNames, out_file=dot_data, class_names= np.unique(y_train), filled=True,  special_characters=True,rotate=False)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png(filename)
img = mpimg.imread(filename)
plt.figure(figsize=(100, 200))
plt.imshow(img,interpolation='nearest')
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Cell In[36], line 6
#       4 out=tree.export_graphviz(drugTree,feature_names=featureNames, out_file=dot_data, class_names= np.unique(y_train), filled=True,  special_characters=True,rotate=False)
#       5 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# ----> 6 graph.write_png(filename)
#       7 img = mpimg.imread(filename)
#       8 plt.figure(figsize=(100, 200))
#
# File ~\anaconda3\Lib\site-packages\pydotplus\graphviz.py:1810, in Dot.__init__.<locals>.<lambda>(path, f, prog)
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#    1805 for frmt in self.formats + ['raw']:
#    1806     self.__setattr__(
#    1807         'write_' + frmt,
#    1808         lambda path,
#    1809         f=frmt,
# -> 1810         prog=self.prog: self.write(path, format=f, prog=prog)
#    1811     )
#    1813     f = self.__dict__['write_' + frmt]
#    1814     f.__doc__ = (
#    1815         '''Refer to the docstring accompanying the'''
#    1816         ''''write' method for more information.'''
#    1817     )
#
# File ~\anaconda3\Lib\site-packages\pydotplus\graphviz.py:1918, in Dot.write(self, path, prog, format)
#    1915         fobj.write(data)
#    1917     else:
# -> 1918         fobj.write(self.create(prog, format))
#    1919 finally:
#    1920     if close:
#
# File ~\anaconda3\Lib\site-packages\pydotplus\graphviz.py:1959, in Dot.create(self, prog, format)
#    1957     self.progs = find_graphviz()
#    1958     if self.progs is None:
# -> 1959         raise InvocationException(
#    1960             'GraphViz\'s executables not found')
#    1962 if prog not in self.progs:
#    1963     raise InvocationException(
#    1964         'GraphViz\'s executable "%s" not found' % prog)
#
# InvocationException: GraphViz's executables not found
